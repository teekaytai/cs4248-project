# %% [markdown]
# <a href="https://colab.research.google.com/github/teekaytai/cs4248-project/blob/ahiyer/simple_t5/simple_t5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GENERAL IMPORTS AND DATASETS

# %%
# !pip install --upgrade simplet5
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.7/527.7 kB 23.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.5/841.5 kB 25.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.4/952.4 kB 27.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 30.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 55.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 58.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 58.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 13.7 MB/s eta 0:00:00
# ...

# %%
from simplet5 import SimpleT5
# Out:
# INFO:pytorch_lightning.utilities.seed:Global seed set to 42

# %%
model = SimpleT5()

# %%
model.from_pretrained("t5", "t5-small")
# Out:
# Downloading:   0%|          | 0.00/2.27k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/231M [00:00<?, ?B/s]

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
train_path = '/content/drive/MyDrive/train.json'
dev_path = '/content/drive/MyDrive/dev.json'

# %%
import pandas as pd

# %%
train_df = pd.read_json(train_path)
train_df_simple = train_df[["original", "corrected"]]
train_df_simple = train_df_simple.rename(columns={"original": "source_text", "corrected": "target_text"})
train_df_simple['source_text'] = "correct: " + train_df_simple['source_text']
eval_df = pd.read_json(dev_path)
eval_df_simple = eval_df[["original", "corrected"]]
eval_df_simple = eval_df_simple.rename(columns={"original": "source_text", "corrected": "target_text"})
eval_df_simple['source_text'] = "correct: " + eval_df_simple['source_text']

# %%
train_df_simple
# Out:
#                                              source_text  \
# 0      correct: My town is a medium size city with ei...
# 1      correct: It has a high density population beca...
# 2      correct: Despite of it is an industrial city ,...
# 3      correct: I recommend visiting the artificial l...
# 4      correct: Pasteries are very common and most of...
# ...                                                  ...
# 35057  correct: In the same way a secret agent has to...
# 35058  correct: Therefore bravery is very important :...
# 35059  correct: A secret agent works undercover , so ...
# 35060  correct: Besides , since his work is secret , ...
# 35061  correct: So , although the life of secret agen...
#
#                                              target_text
# 0      My town is a medium - sized city with eighty t...
# 1      It has a high - density population because of ...
# 2      Although it is an industrial city , there are ...
# ...

# %%
eval_df_simple
# Out:
#                                             source_text  \
# 0     correct: It 's difficult answer at the questio...
# 1     correct: When I was younger I used to say that...
# 2                          correct: I do n't know why .
# 3     correct: I would like to study Psychology beca...
# 4     correct: It 's difficult because I 'll have to...
# ...                                                 ...
# 4476              correct: How much violence is there ?
# 4477  correct: The most violent cartoons are ' Teena...
# 4478  correct: As for the shows containing sinister ...
# 4479  correct: The cause for television violence is ...
# 4480  correct: The infamous V - chip may stop some s...
#
#                                             target_text
# 0     It 's difficult to answer the question " what ...
# 1     When I was younger , I used to say that I want...
# 2                                   I do n't know why .
# 3     I would like to study Psychology , because one...
# ...

# %%
model.train(train_df = train_df_simple,
            eval_df = eval_df_simple,
            source_max_token_len = 512,
            target_max_token_len = 128,
            batch_size = 16,
            max_epochs = 1,
            use_gpu = True,
            outputdir = "outputs",
            early_stopping_patience_epochs=0)
# Out:
# INFO:pytorch_lightning.utilities.distributed:GPU available: True, used: True
# INFO:pytorch_lightning.utilities.distributed:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.distributed:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.accelerators.gpu:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# WARNING:pytorch_lightning.loggers.tensorboard:Missing logger folder: /content/lightning_logs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name  | Type                       | Params
# -----------------------------------------------------
# 0 | model | T5ForConditionalGeneration | 60.5 M
# -----------------------------------------------------
# 60.5 M    Trainable params
# 0         Non-trainable params
# 60.5 M    Total params
# 242.026   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# ...
